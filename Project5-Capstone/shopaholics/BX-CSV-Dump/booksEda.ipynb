# %%
# !ls
import pandas as pd
# Out:
# BX-Book-Ratings.csv      BX-Books.csv             booksEda.ipynb
# BX-Books-munged.csv      BX-Users.csv             shopaholicsExplore.ipynb

# %%
dfBooks = pd.read_csv("./BX-Books-munged.csv", delimiter=";", escapechar="\\")
dfUsers =  pd.read_csv("./BX-Users.csv", delimiter=";", escapechar="\\")
dfRatings = pd.read_csv("./BX-Book-Ratings.csv", delimiter=";", escapechar="\\")

# %%
dfUsers
# Out:
#         User-ID                                          Location   Age
# 0             1                                nyc, new york, usa   NaN
# 1             2                         stockton, california, usa  18.0
# 2             3                   moscow, yukon territory, russia   NaN
# 3             4                         porto, v.n.gaia, portugal  17.0
# 4             5                farnborough, hants, united kingdom   NaN
# 5             6                     santa monica, california, usa  61.0
# 6             7                               washington, dc, usa   NaN
# 7             8                          timmins, ontario, canada   NaN
# 8             9                        germantown, tennessee, usa   NaN
# 9            10                        albacete, wisconsin, spain  26.0
# 10           11                    melbourne, victoria, australia  14.0
# 11           12                       fort bragg, california, usa   NaN
# ...
