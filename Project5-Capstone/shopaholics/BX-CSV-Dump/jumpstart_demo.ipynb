# %%
sc

# %%
sc.version

# %%
import pandas as pd

# %%
myData = sqlContext.sql("select `User-ID` from ratings")

# %%
myData.show()

# %%
myData2 = sqlContext.sql("select * from ratings")

# %%
myData2.show()

# %%
import os
import sys
from itertools import islice
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
df = sqlContext.sql("SELECT u.UserID, u.Location, u.Age from users u where location like '%usa%'")
#df.show()
df.printSchema()

# %%
#Convert Spark Dataframe to pandas DataFrame
#df_pd = spark.createDataFrame(df)
dfPD = df.toPandas()

# %%
type(dfPD)

# %%
# Select everybody, but increment the age by 1
df.describe()

# %%
# Select people older than 21
df.filter(df['Age'] > 21).show()
## age name
## 30  Andy

# %%
# Count people by age
df.groupBy('Age').count().show()
## age  count
## null 1
## 19   1
## 30   1

# %%
df.collect()

# %%
df.count()

# %%
df.filter(df['Age'] > 21).show()

# %%
df.groupBy('Age').count().show()

# %%
df_books = sqlContext.sql("SELECT * from books")
#df.show()
df_books.printSchema()

# %%
df_books = df_books.toPandas()
df_books.describe()

# %%
df_ratings = sqlContext.sql("SELECT * from ratings")
#df.show()
df_ratings.printSchema()
